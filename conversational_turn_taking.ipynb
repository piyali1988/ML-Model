# %%
cd Desktop
# Out:
# C:\Users\dbyrne\Desktop

# %%
import pandas as pd
df = pd.read_csv('test_output.csv')

# %%
df.drop(columns=['Unnamed: 2'], inplace=True)

# %%
df = df.fillna('o')

# %%
c_speech = df['c_speech']

# %%
p_speech=df['p_speech']

p_speech = ['parent: ' + p for p in p_speech]

# %%
c_speech = ['child: ' + c for c in c_speech]

# %%
d=list(zip(p_speech, c_speech))

# %%
new_df = pd.DataFrame(d, columns = ['p_speech', 'c_speech'])

# %%
new_df['p_speech'] = new_df['p_speech'].replace('parent: o', ' ')

# %%
new_df['c_speech'] = new_df['c_speech'].replace('child: o', ' ')

# %%
new_df['p_speech'] + ' ' +   new_df['c_speech']
# Out:
# 0               parent: they putting us on camera girl.
# 1
# 2                                   parent: movie star.
# 3
# 4                                          parent: yes.
# 5
# 6                                          parent: yes.
# 7
# 8                                           parent: ---
# 9
# 10                                          parent: ok.
# 11
# 12                           parent: ooh child:  Amari@n.
# 13
# 14                        parent: we got some of these.
# 15
# 16                parent: don't you have these already?
# 17
# 18                                             child: no.
# 19
# 20      parent: what about the cups you got at -- you ...
# 21
# 22                              parent: stackable cups.
# 23
# 24                                        parent: look.
# 25
# 26      parent: what+about the stack ones we got the o...
# 27
# 28                                          parent: ###
# 29
#                               ...
# 1928
# ...

# %%
new_df= new_df.drop(new_df[new_df['c_speech'] == 'child: o'].index)

# %%
new_df =new_df.drop(new_df[new_df['p_speech'] == 'parent: o'].index)

# %%
new_df
# Out:
#                                                p_speech  \
# 12                                          parent: ooh
# 40                                   parent: fix -- ooh
# 68                                           parent: ok
# 72                                       parent: aw man
# 74                                          parent: huh
# 79                                 parent: what's that?
# 105                                    parent: correct.
# 154                          parent: correct -- correct
# 158                                   parent: let's see
# 162                                     parent: correct
# 178                                          parent: no
# 185               parent: that looks like grapes to me.
# 224                                          parent: no
# 232                                          parent: no
# 274                                          parent: ok
# 282                                          parent: oh
# ...

# %%
new_df['merge_speech'] = new_df['p_speech'] + '__' + new_df['c_speech']

# %%
new_df = new_df.drop(new_df[new_df['merge_speech'] == 'parent: o__child: o'].index)

# %%
mspeech=new_df['merge_speech']

# %%
[s for s in mspeech]
# Out:
# ['parent: they putting us on camera girl.__child: o',
#  'parent: movie star.__child: o',
#  'parent: yes.__child: o',
#  'parent: yes.__child: o',
#  'parent: ---__child: o',
#  'parent: ok.__child: o',
#  'parent: ooh__child:  Amari@n.',
#  'parent: we got some of these.__child: o',
#  "parent: don't you have these already?__child: o",
#  'parent: o__child: no.',
#  'parent: what about the cups you got at -- you and Brycon@n.__child: o',
#  'parent: stackable cups.__child: o',
#  'parent: look.__child: o',
#  'parent: what+about the stack ones we got the other day?__child: o',
#  'parent: ###__child: o',
#  'parent: come on.__child: o',
#  "parent: o__child: let's play.",
#  "parent: let's play.__child: o",
#  'parent: get the cups.__child: o',
#  'parent: ok.__child: o',
#  'parent: fix -- ooh__child:  look they got food',
#  'parent: fix Mommy a hamburger.__child: o',
#  "parent: that's the meat.__child: o",
#  'parent: and the bread.__child: o',
# ...

# %%
num = ['one', 'two', 'three', 'four', 'five']

fs = ["there's two dinosaurs", "it's yellow", "this is four", "high-five"]

fake_speech = pd.DataFrame(fs)

ts = fake_speech[0]

# %%
[s.split() for s in ts]
# Out:
# [["there's", 'two', 'dinosaurs'],
#  ["it's", 'yellow'],
#  ['this', 'is', 'four'],
#  ['high-five']]

# %%
num_coding
# Out:
# [0, 0, 0, 0]

# %%
p=[s.split() for s in ts]

# %%
for p in p:
    if p in num:
        print('yeys')
    else:
        print('k.')
# Out:
# k.
# k.
# k.
# k.

# %%
def numCode(n):
    if 'four' in n:
        return 1
    if 'two' in n:
        return 1
    else:
        return 0

# %%
fake_speech['a'] = ''

# %%
fake_speech['c']=fake_speech[0].apply(numCode)

# %%
fake_speech['a'][fake_speech[0].str.contains('four' and 'two')] = 1

# %%
fake_speech['b'] = fake_speech[0].map(lambda x: "1" if "four" or "two" in x else "0")

# %%
fake_speech
# Out:
#                        0  a  b  c
# 0  there's two dinosaurs  1  1  1
# 1            it's yellow     1  0
# 2           this is four     1  1
# 3              high-five     1  0

# %%
cd Documents
# Out:
# C:\Users\dbyrne\Documents

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is A689-013B
#
#  Directory of C:\Users\dbyrne\Documents
#
# 05/16/2019  04:09 PM    <DIR>          .
# 05/16/2019  04:09 PM    <DIR>          ..
# 04/18/2019  04:28 PM         1,137,164 .~p_speech_vs1.csv
# 05/14/2019  05:58 PM    <DIR>          .ipynb_checkpoints
# 04/21/2019  10:50 PM            11,498 1913_VS1.csv
# 05/13/2019  02:56 PM           114,403 5_7_19_ml_cleaning_num_space.ipynb
# 05/06/2019  02:55 PM           228,754 clean_concatenated_num
# 05/02/2019  05:41 PM           116,041 clean_spatial
# 05/01/2019  10:54 AM            86,470 clean_spatial_master.csv
# 05/03/2019  03:52 PM           203,566 clean_spatial_VS2
# 05/03/2019  04:20 PM           181,012 clean_spatial_VS2.csv
# 05/06/2019  01:56 PM            87,100 clean_spatial1
# 05/06/2019  01:56 PM            87,100 clean_spatial1.csv
# 05/02/2019  05:41 PM           120,589 clean_spatial2
# 03/25/2019  12:42 PM               223 cloud_env.bat
# ...

# %%
ing_verb_noun_df = pd.read_csv('Wordswithin.csv')

# %%
ing_verb_noun_df['verb'] = ing_verb_noun_df['First word (contains "in")']

# %%
ing_verb_noun_df.drop(columns=['First word (contains "in")'], inplace=True)

# %%
ing_verb_noun_df['noun'] = ing_verb_noun_df['Second word']

# %%
ing_verb_noun_df.drop(columns=['Second word'], inplace=True)

# %%
ing_verb_noun_df['verb'] = ing_verb_noun_df['verb'].str.lower()

# %%
ing_verb_noun_df['noun'] = ing_verb_noun_df['noun'].str.lower()

# %%
ing_verb_noun_df['phrase'] = ing_verb_noun_df['verb'] + " "  + ing_verb_noun_df['noun']

# %%
ing_verb_noun_df
# Out:
#               verb          noun                  phrase
# 0        absorbing        liquid        absorbing liquid
# 1        accepting  applicatoins  accepting applicatoins
# 2        accessing          data          accessing data
# 3     accumulating         items      accumulating items
# 4        achieving         goals         achieving goals
# 5           aching          back             aching back
# 6        acquiring          food          acquiring food
# 7           adding       numbers          adding numbers
# 8       addressing     envelopes    addressing envelopes
# 9        adjoining          room          adjoining room
# 10   administering      medicine  administering medicine
# 11        admiring           art            admiring art
# 12        adopting          kids           adopting kids
# 13     advertising      products    advertising products
# 14     alternating       pattern     alternating pattern
# ...

# %%
sort_speech = pd.read_csv('Parent Child Speech Merge 250_VS1.csv')

# %%
sorted_df = sort_speech.sort_values(by=['onset', 'offset'], ascending=[True, False])

# %%
sorted_df.to_csv('test_sorted_turns.csv')

# %%
[u for u in utts]
# Out:
# ["where's the ball?",
#  'look.',
#  'give me the ball.',
#  'this one.',
#  "this one's the ball.",
#  'roll it.',
#  'roll it.',
#  'good job.',
#  'yeah.',
#  'ah, uhoh.',
#  'yay.',
#  '###',
#  'want to dance?',
#  'hmm?',
#  '###.',
#  '###',
#  '###',
#  'baila@f',
#  'you want to dance?',
#  'no?',
#  'good job.',
#  'alright, you want them together?',
#  'want to dance?',
#  'hmm?',
#  'good job.',
#  'ball.',
#  'ball.',
#  'throw it.',
#  'throw the ball.',
#  'do you see the baby?',
#  'ah, baby?',
#  'baby.',
#  'look.',
#  '### kiss?',
#  'aw, kiss.',
#  'a hug?',
#  'you want to hug it?',
#  'you want to hug baby?',
#  'hmm?',
#  '---',
#  'besito@f.',
#  'besito@f.',
#  'besito@f.',
#  'no?',
#  'no more?',
#  'just one?',
#  'there you go.',
#  'poor baby.',
#  'look at the horse.',
#  'horse.',
#  'this is a cat.',
#  'oink -- oink.',
#  'a pig.',
#  'a pink pig.',
#  '###',
#  'animals.',
#  'which one?',
#  'the baby?',
# ...

# %%
labels =sorted_df['column']

# %%
turn_count = 0

for speaker in labels:
    if speaker == 'p_speech':
        continue
    if speaker == 'c_speech':
        turn_count += 1

# %%
turn_count
# Out:
# 3

# %%
sorted_df['count'] = sorted_df.groupby((sorted_df['column'] != sorted_df['column'].shift(1)).cumsum()).cumcount()+1

# %%
sorted_df['count'] = sorted_df.groupby('column').cumcount()

# %%
sorted_df
# Out:
#         file    column  ordinal    onset   offset  \
# 3    250_VS1  p_speech        1     5998     6500
# 4    250_VS1  p_speech        2     6863     7259
# 5    250_VS1  p_speech        3     7516     8183
# 6    250_VS1  p_speech        4     8333     8744
# 7    250_VS1  p_speech        5     8810     9965
# 8    250_VS1  p_speech        6    11658    12308
# 9    250_VS1  p_speech        7    13177    13496
# 10   250_VS1  p_speech        8    13756    14684
# 11   250_VS1  p_speech        9    29061    29516
# 12   250_VS1  p_speech       10    29516    30854
# 13   250_VS1  p_speech       11    40761    41843
# 14   250_VS1  p_speech       12    44682    45110
# 15   250_VS1  p_speech       13    45732    46727
# 16   250_VS1  p_speech       14    47102    47618
# 17   250_VS1  p_speech       15    49567    50199
# 18   250_VS1  p_speech       16    50200    51099
# 19   250_VS1  p_speech       17    51100    52399
# 20   250_VS1  p_speech       18    54132    54779
# ...

# %%
(sorted_df['column'] != sorted_df['column'].shift(axis=0)).sum(axis=0)
# Out:
# 7

# %%
import pandas as pd
import glob

folder = 'RY merges'
file = glob.glob(folder + "\*.csv")

dfs = []
for file in file:
    df = pd.read_csv(file)
    dfs.append(df)

# %%
vs1_1272=dfs[0]
vs1_1293=dfs[1]
vs1_1305=dfs[2]
vs1_1311=dfs[3]
vs1_1321=dfs[4]
vs1_1365=dfs[5]
vs1_1375=dfs[6]
vs1_1442=dfs[7]
vs1_1445=dfs[8]
vs1_1482=dfs[9]
vs1_1492=dfs[10]
vs1_1528=dfs[11]
vs1_1560=dfs[12]
vs1_1568=dfs[13]
vs1_1584=dfs[14]
vs1_1612=dfs[15]
vs1_1622=dfs[16]
vs1_1624=dfs[17]
vs1_1648=dfs[18]
vs1_1658=dfs[19]
vs1_1728=dfs[20]
vs1_1750=dfs[21]
vs1_1775=dfs[22]
vs1_1777=dfs[23]
vs1_1779=dfs[24]
vs1_1782=dfs[25]
vs1_1800=dfs[26]
vs1_1802=dfs[27]
vs1_1816=dfs[28]
vs1_1820=dfs[29]
vs1_1824=dfs[30]
vs1_1845_1=dfs[31]
vs1_1845_2=dfs[32]
vs1_1845_3=dfs[33]
vs1_1913=dfs[34]
vs1_1915=dfs[35]
vs1_1935=dfs[36]
vs1_1969=dfs[37]
vs1_1992=dfs[38]
vs1_1998=dfs[39]
vs1_2006=dfs[40]
vs1_2015=dfs[41]
vs1_2031=dfs[42]
vs1_2049=dfs[43]
vs1_2067=dfs[44]
vs1_2071=dfs[45]
vs1_2077=dfs[46]
vs1_2087=dfs[47]
vs1_2089=dfs[48]
vs1_2103=dfs[49]
vs1_2107=dfs[50]
vs1_2111=dfs[51]
vs1_2134=dfs[52]
vs1_2136=dfs[53]
vs1_2151=dfs[54]
vs1_2157=dfs[55]
vs1_2185=dfs[56]
vs1_2191=dfs[57]
vs1_2194=dfs[58]
vs1_2204=dfs[59]
vs1_2211=dfs[60]
vs1_2219=dfs[61]
vs1_2228=dfs[62]
vs1_2244=dfs[63]
vs1_2250=dfs[64]
vs1_2252=dfs[65]
vs1_2256=dfs[66]
vs1_2269=dfs[67]
vs1_2274=dfs[68]
vs1_2288=dfs[69]
vs1_2292=dfs[70]
vs1_2306=dfs[71]
vs1_2322=dfs[72]
vs1_2333=dfs[73]
vs1_2335=dfs[74]
vs1_1269=dfs[75]

# %%
sorted_df_1272 = vs1_1272.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_1293 = vs1_1293.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_1305 = vs1_1305.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_1311 = vs1_1311.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_1321 = vs1_1321.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_1365 = vs1_1365.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_1375 = vs1_1375.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_1442 = vs1_1442.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_1445 = vs1_1445.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_1482 = vs1_1482.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_1492 = vs1_1492.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_1528 = vs1_1528.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_1560 = vs1_1560.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_1568 = vs1_1568.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_1584 = vs1_1584.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_1612 = vs1_1612.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_1622 = vs1_1622.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_1624 = vs1_1624.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_1648 = vs1_1648.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_1658 = vs1_1658.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_1728 = vs1_1728.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_1750 = vs1_1750.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_1775 = vs1_1775.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_1777 = vs1_1777.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_1779 = vs1_1779.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_1782 = vs1_1782.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_1800 = vs1_1800.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_1802 = vs1_1802.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_1816 = vs1_1816.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_1820 = vs1_1820.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_1824 = vs1_1824.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_1845_1 = vs1_1845_1.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_1845_2 = vs1_1845_2.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_1845_3 = vs1_1845_3.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_1913 = vs1_1913.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_1915 = vs1_1915.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_1935 = vs1_1935.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_1969 = vs1_1969.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_1992 = vs1_1992.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_1998 = vs1_1998.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_2006 = vs1_2006.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_2015 = vs1_2015.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_2031 = vs1_2031.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_2049 = vs1_2049.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_2067 = vs1_2067.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_2071 = vs1_2071.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_2077 = vs1_2077.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_2087 = vs1_2087.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_2089 = vs1_2089.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_2103 = vs1_2103.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_2107 = vs1_2107.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_2111 = vs1_2111.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_2134 = vs1_2134.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_2136 = vs1_2136.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_2151 = vs1_2151.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_2157 = vs1_2157.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_2185 = vs1_2185.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_2191 = vs1_2191.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_2194 = vs1_2194.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_2204 = vs1_2204.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_2211 = vs1_2211.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_2219 = vs1_2219.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_2228 = vs1_2228.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_2244 = vs1_2244.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_2250 = vs1_2250.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_2252 = vs1_2252.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_2256 = vs1_2256.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_2269 = vs1_2269.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_2274 = vs1_2274.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_2288 = vs1_2288.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_2292 = vs1_2292.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_2306 = vs1_2306.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_2322 = vs1_2322.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_2333 = vs1_2333.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_2335 = vs1_2335.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_1269 = vs1_1269.sort_values(by=['onset', 'offset'], ascending=[True, False])

# %%
sorted_df_1272['CTC'] = (sorted_df_1272['column'] != sorted_df_1272['column'].shift(axis=0)).sum(axis=0)

# %%
sorted_df_1293['CTC'] = (sorted_df_1293['column'] != sorted_df_1293['column'].shift(axis=0)).sum(axis=0)
sorted_df_1305['CTC'] = (sorted_df_1305['column'] != sorted_df_1305['column'].shift(axis=0)).sum(axis=0)
sorted_df_1311['CTC'] = (sorted_df_1311['column'] != sorted_df_1311['column'].shift(axis=0)).sum(axis=0)
sorted_df_1321['CTC'] = (sorted_df_1321['column'] != sorted_df_1321['column'].shift(axis=0)).sum(axis=0)
sorted_df_1365['CTC'] = (sorted_df_1365['column'] != sorted_df_1365['column'].shift(axis=0)).sum(axis=0)
sorted_df_1375['CTC'] = (sorted_df_1375['column'] != sorted_df_1375['column'].shift(axis=0)).sum(axis=0)
sorted_df_1442['CTC'] = (sorted_df_1442['column'] != sorted_df_1442['column'].shift(axis=0)).sum(axis=0)
sorted_df_1445['CTC'] = (sorted_df_1445['column'] != sorted_df_1445['column'].shift(axis=0)).sum(axis=0)
sorted_df_1482['CTC'] = (sorted_df_1482['column'] != sorted_df_1482['column'].shift(axis=0)).sum(axis=0)
sorted_df_1492['CTC'] = (sorted_df_1492['column'] != sorted_df_1492['column'].shift(axis=0)).sum(axis=0)
sorted_df_1528['CTC'] = (sorted_df_1528['column'] != sorted_df_1528['column'].shift(axis=0)).sum(axis=0)
sorted_df_1560['CTC'] = (sorted_df_1560['column'] != sorted_df_1560['column'].shift(axis=0)).sum(axis=0)
sorted_df_1568['CTC'] = (sorted_df_1568['column'] != sorted_df_1568['column'].shift(axis=0)).sum(axis=0)
sorted_df_1584['CTC'] = (sorted_df_1584['column'] != sorted_df_1584['column'].shift(axis=0)).sum(axis=0)
sorted_df_1612['CTC'] = (sorted_df_1612['column'] != sorted_df_1612['column'].shift(axis=0)).sum(axis=0)
sorted_df_1622['CTC'] = (sorted_df_1622['column'] != sorted_df_1622['column'].shift(axis=0)).sum(axis=0)
sorted_df_1624['CTC'] = (sorted_df_1624['column'] != sorted_df_1624['column'].shift(axis=0)).sum(axis=0)
sorted_df_1648['CTC'] = (sorted_df_1648['column'] != sorted_df_1648['column'].shift(axis=0)).sum(axis=0)
sorted_df_1658['CTC'] = (sorted_df_1658['column'] != sorted_df_1658['column'].shift(axis=0)).sum(axis=0)
sorted_df_1728['CTC'] = (sorted_df_1728['column'] != sorted_df_1728['column'].shift(axis=0)).sum(axis=0)
sorted_df_1800['CTC'] = (sorted_df_1800['column'] != sorted_df_1800['column'].shift(axis=0)).sum(axis=0)
sorted_df_1802['CTC'] = (sorted_df_1802['column'] != sorted_df_1802['column'].shift(axis=0)).sum(axis=0)
sorted_df_1816['CTC'] = (sorted_df_1816['column'] != sorted_df_1816['column'].shift(axis=0)).sum(axis=0)
sorted_df_1820['CTC'] = (sorted_df_1820['column'] != sorted_df_1820['column'].shift(axis=0)).sum(axis=0)
sorted_df_1824['CTC'] = (sorted_df_1824['column'] != sorted_df_1824['column'].shift(axis=0)).sum(axis=0)
sorted_df_1845_1['CTC'] = (sorted_df_1845_1['column'] != sorted_df_1845_1['column'].shift(axis=0)).sum(axis=0)
sorted_df_1845_2['CTC'] = (sorted_df_1845_2['column'] != sorted_df_1845_2['column'].shift(axis=0)).sum(axis=0)
sorted_df_1845_3['CTC'] = (sorted_df_1845_3['column'] != sorted_df_1845_3['column'].shift(axis=0)).sum(axis=0)
sorted_df_1913['CTC'] = (sorted_df_1913['column'] != sorted_df_1913['column'].shift(axis=0)).sum(axis=0)
sorted_df_1915['CTC'] = (sorted_df_1915['column'] != sorted_df_1915['column'].shift(axis=0)).sum(axis=0)
sorted_df_1935['CTC'] = (sorted_df_1935['column'] != sorted_df_1935['column'].shift(axis=0)).sum(axis=0)
sorted_df_1969['CTC'] = (sorted_df_1969['column'] != sorted_df_1969['column'].shift(axis=0)).sum(axis=0)
sorted_df_1992['CTC'] = (sorted_df_1992['column'] != sorted_df_1992['column'].shift(axis=0)).sum(axis=0)
sorted_df_1998['CTC'] = (sorted_df_1998['column'] != sorted_df_1998['column'].shift(axis=0)).sum(axis=0)
sorted_df_2006['CTC'] = (sorted_df_2006['column'] != sorted_df_2006['column'].shift(axis=0)).sum(axis=0)
sorted_df_2015['CTC'] = (sorted_df_2015['column'] != sorted_df_2015['column'].shift(axis=0)).sum(axis=0)
sorted_df_2031['CTC'] = (sorted_df_2031['column'] != sorted_df_2031['column'].shift(axis=0)).sum(axis=0)
sorted_df_2049['CTC'] = (sorted_df_2049['column'] != sorted_df_2049['column'].shift(axis=0)).sum(axis=0)
sorted_df_2067['CTC'] = (sorted_df_2067['column'] != sorted_df_2067['column'].shift(axis=0)).sum(axis=0)
sorted_df_2071['CTC'] = (sorted_df_2071['column'] != sorted_df_2071['column'].shift(axis=0)).sum(axis=0)
sorted_df_2077['CTC'] = (sorted_df_2077['column'] != sorted_df_2077['column'].shift(axis=0)).sum(axis=0)
sorted_df_2087['CTC'] = (sorted_df_2087['column'] != sorted_df_2087['column'].shift(axis=0)).sum(axis=0)
sorted_df_2089['CTC'] = (sorted_df_2089['column'] != sorted_df_2089['column'].shift(axis=0)).sum(axis=0)
sorted_df_2103['CTC'] = (sorted_df_2103['column'] != sorted_df_2103['column'].shift(axis=0)).sum(axis=0)
sorted_df_2107['CTC'] = (sorted_df_2107['column'] != sorted_df_2107['column'].shift(axis=0)).sum(axis=0)
sorted_df_2111['CTC'] = (sorted_df_2111['column'] != sorted_df_2111['column'].shift(axis=0)).sum(axis=0)
sorted_df_2134['CTC'] = (sorted_df_2134['column'] != sorted_df_2134['column'].shift(axis=0)).sum(axis=0)
sorted_df_2136['CTC'] = (sorted_df_2136['column'] != sorted_df_2136['column'].shift(axis=0)).sum(axis=0)
sorted_df_2151['CTC'] = (sorted_df_2151['column'] != sorted_df_2151['column'].shift(axis=0)).sum(axis=0)
sorted_df_2157['CTC'] = (sorted_df_2157['column'] != sorted_df_2157['column'].shift(axis=0)).sum(axis=0)
sorted_df_2185['CTC'] = (sorted_df_2185['column'] != sorted_df_2185['column'].shift(axis=0)).sum(axis=0)
sorted_df_2191['CTC'] = (sorted_df_2191['column'] != sorted_df_2191['column'].shift(axis=0)).sum(axis=0)
sorted_df_2194['CTC'] = (sorted_df_2194['column'] != sorted_df_2194['column'].shift(axis=0)).sum(axis=0)
sorted_df_2204['CTC'] = (sorted_df_2204['column'] != sorted_df_2204['column'].shift(axis=0)).sum(axis=0)
sorted_df_2211['CTC'] = (sorted_df_2211['column'] != sorted_df_2211['column'].shift(axis=0)).sum(axis=0)
sorted_df_2219['CTC'] = (sorted_df_2219['column'] != sorted_df_2219['column'].shift(axis=0)).sum(axis=0)
sorted_df_2228['CTC'] = (sorted_df_2228['column'] != sorted_df_2228['column'].shift(axis=0)).sum(axis=0)
sorted_df_2244['CTC'] = (sorted_df_2244['column'] != sorted_df_2244['column'].shift(axis=0)).sum(axis=0)
sorted_df_2250['CTC'] = (sorted_df_2250['column'] != sorted_df_2250['column'].shift(axis=0)).sum(axis=0)
sorted_df_2252['CTC'] = (sorted_df_2252['column'] != sorted_df_2252['column'].shift(axis=0)).sum(axis=0)
sorted_df_2256['CTC'] = (sorted_df_2256['column'] != sorted_df_2256['column'].shift(axis=0)).sum(axis=0)
sorted_df_2269['CTC'] = (sorted_df_2269['column'] != sorted_df_2269['column'].shift(axis=0)).sum(axis=0)
sorted_df_2274['CTC'] = (sorted_df_2274['column'] != sorted_df_2274['column'].shift(axis=0)).sum(axis=0)
sorted_df_2288['CTC'] = (sorted_df_2288['column'] != sorted_df_2288['column'].shift(axis=0)).sum(axis=0)
sorted_df_2292['CTC'] = (sorted_df_2292['column'] != sorted_df_2292['column'].shift(axis=0)).sum(axis=0)
sorted_df_2306['CTC'] = (sorted_df_2306['column'] != sorted_df_2306['column'].shift(axis=0)).sum(axis=0)
sorted_df_2322['CTC'] = (sorted_df_2322['column'] != sorted_df_2322['column'].shift(axis=0)).sum(axis=0)
sorted_df_2333['CTC'] = (sorted_df_2333['column'] != sorted_df_2333['column'].shift(axis=0)).sum(axis=0)
sorted_df_2335['CTC'] = (sorted_df_2335['column'] != sorted_df_2335['column'].shift(axis=0)).sum(axis=0)
sorted_df_1269['CTC'] = (sorted_df_1269['column'] != sorted_df_1269['column'].shift(axis=0)).sum(axis=0)

# %%
sorted_df_2111
# Out:
#          file    column  ordinal    onset   offset  \
# 5    2111_VS1  p_speech        1    14968    16052
# 6    2111_VS1  p_speech        2    17695    18630
# 7    2111_VS1  p_speech        3    29628    30124
# 8    2111_VS1  p_speech        4    30459    30954
# 9    2111_VS1  p_speech        5    43108    43565
# 10   2111_VS1  p_speech        6    44152    45012
# 11   2111_VS1  p_speech        7    45441    45936
# 12   2111_VS1  p_speech        8    50292    50664
# 13   2111_VS1  p_speech        9    54714    55116
# 14   2111_VS1  p_speech       10    59697    60193
# 15   2111_VS1  p_speech       11    61803    62578
# 16   2111_VS1  p_speech       12    63877    64125
# 17   2111_VS1  p_speech       13    65043    65476
# 18   2111_VS1  p_speech       14    67548    67827
# 19   2111_VS1  p_speech       15    68475    69156
# 20   2111_VS1  p_speech       16    71562    72173
# 21   2111_VS1  p_speech       17    73590    74023
# ...

# %%
import pandas as pd
import glob

folder = 'VS1_merge_csvs'
file = glob.glob(folder + "\*.csv")

dfs = []
for file in file:
    df = pd.read_csv(file)
    dfs.append(df)

# %%
file
# Out:
# 'VS1_merge_csvs\\Parent Child Speech Merge 709_VS1.csv'

# %%
len(dfs)
# Out:
# 50

# %%
vs1_250=dfs[0]
vs1_256=dfs[1]
vs1_262=dfs[2]
vs1_264=dfs[3]
vs1_266=dfs[4]
vs1_268=dfs[5]
vs1_272=dfs[6]
vs1_289=dfs[7]
vs1_293=dfs[8]
vs1_297=dfs[9]
vs1_304=dfs[10]
vs1_306=dfs[11]
vs1_314=dfs[12]
vs1_320=dfs[13]
vs1_335=dfs[14]
vs1_337=dfs[15]
vs1_339=dfs[16]
vs1_353=dfs[17]
vs1_368=dfs[18]
vs1_371=dfs[19]
vs1_373=dfs[20]
vs1_375=dfs[21]
vs1_381=dfs[22]
vs1_409=dfs[23]
vs1_413=dfs[24]
vs1_438=dfs[25]
vs1_440=dfs[26]
vs1_454=dfs[27]
vs1_460=dfs[28]
vs1_462=dfs[29]
vs1_464=dfs[30]
vs1_475=dfs[31]
vs1_486=dfs[32]
vs1_501=dfs[33]
vs1_503=dfs[34]
vs1_527=dfs[35]
vs1_543=dfs[36]
vs1_547=dfs[37]
vs1_553=dfs[38]
vs1_555=dfs[39]
vs1_565=dfs[40]
vs1_581=dfs[41]
vs1_614=dfs[42]
vs1_631=dfs[43]
vs1_647=dfs[44]
vs1_649=dfs[45]
vs1_695=dfs[46]
vs1_697=dfs[47]
vs1_703=dfs[48]
vs1_709=dfs[49]

# %%
sorted_df_250 = vs1_250.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_256 = vs1_256.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_262 = vs1_262.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_264 = vs1_264.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_266 = vs1_266.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_268 = vs1_268.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_272 = vs1_272.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_289 = vs1_289.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_293 = vs1_293.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_297 = vs1_297.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_304 = vs1_304.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_306 = vs1_306.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_314 = vs1_314.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_320 = vs1_320.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_335 = vs1_335.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_337 = vs1_337.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_339 = vs1_339.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_353 = vs1_353.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_368 = vs1_368.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_371 = vs1_371.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_373 = vs1_373.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_375 = vs1_375.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_381 = vs1_381.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_409 = vs1_409.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_413 = vs1_413.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_438 = vs1_438.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_440 = vs1_440.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_454 = vs1_454.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_460 = vs1_460.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_462 = vs1_462.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_464 = vs1_464.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_475 = vs1_475.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_486 = vs1_486.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_501 = vs1_501.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_503 = vs1_503.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_527 = vs1_527.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_543 = vs1_543.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_547 = vs1_547.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_553 = vs1_553.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_555 = vs1_555.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_565 = vs1_565.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_581 = vs1_581.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_614 = vs1_614.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_631 = vs1_631.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_647 = vs1_647.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_649 = vs1_649.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_695 = vs1_695.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_697 = vs1_697.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_703 = vs1_703.sort_values(by=['onset', 'offset'], ascending=[True, False])
sorted_df_709 = vs1_709.sort_values(by=['onset', 'offset'], ascending=[True, False])

# %%
sorted_dfs = []
for df in dfs:
    df=df.sort_values(by=['onset', 'offset'], ascending=[True, False])
    sorted_dfs.append(df)

# %%
dfs = []

for df in sorted_dfs:
    df['CTC'] = ' '
    df['CTC'] =  (df['column'] != df['column'].shift(axis=0)).sum(axis=0)
    dfs.append(df)

# %%
vs1_250=dfs[0]
vs1_256=dfs[1]
vs1_262=dfs[2]
vs1_264=dfs[3]
vs1_266=dfs[4]
vs1_268=dfs[5]
vs1_272=dfs[6]
vs1_289=dfs[7]
vs1_293=dfs[8]
vs1_297=dfs[9]
vs1_304=dfs[10]
vs1_306=dfs[11]
vs1_314=dfs[12]
vs1_320=dfs[13]
vs1_335=dfs[14]
vs1_337=dfs[15]
vs1_339=dfs[16]
vs1_353=dfs[17]
vs1_368=dfs[18]
vs1_371=dfs[19]
vs1_373=dfs[20]
vs1_375=dfs[21]
vs1_381=dfs[22]
vs1_409=dfs[23]
vs1_413=dfs[24]
vs1_438=dfs[25]
vs1_440=dfs[26]
vs1_454=dfs[27]
vs1_460=dfs[28]
vs1_462=dfs[29]
vs1_464=dfs[30]
vs1_475=dfs[31]
vs1_486=dfs[32]
vs1_501=dfs[33]
vs1_503=dfs[34]
vs1_527=dfs[35]
vs1_543=dfs[36]
vs1_547=dfs[37]
vs1_553=dfs[38]
vs1_555=dfs[39]
vs1_565=dfs[40]
vs1_581=dfs[41]
vs1_614=dfs[42]
vs1_631=dfs[43]
vs1_647=dfs[44]
vs1_649=dfs[45]
vs1_695=dfs[46]
vs1_697=dfs[47]
vs1_703=dfs[48]
vs1_709=dfs[49]

# %%
c = [c for c in vs1_631['column'] if c == 'c_speech']

# %%
vs1_555
# Out:
#         file    column  ordinal    onset   offset                      utts  \
# 2    555_VS1  p_speech        1     4356     5316                       ---
# 3    555_VS1  p_speech        2     9639    10353           here Tristan@n.
# 4    555_VS1  p_speech        3    10864    11317                     look.
# 5    555_VS1  p_speech        4    15550    16038          there's chicken.
# 6    555_VS1  p_speech        5    16070    17766         you like chicken.
# 7    555_VS1  p_speech        6    18385    18776                     look.
# 8    555_VS1  p_speech        7    19465    21680        you bang the cups.
# 9    555_VS1  p_speech        8    26397    26821                     here.
# 10   555_VS1  p_speech        9    27175    27950            now you do it.
# 11   555_VS1  p_speech       10    28411    29110                you do it.
# 12   555_VS1  p_speech       11    41981    42934      want to do a puzzle?
# ...

# %%
import pandas as pd
import glob

folder = 'merged speech'
file = glob.glob(folder + "\*.csv")

# %%
dfs = []
for file in file:
    df = pd.read_csv(file, encoding = "ISO-8859-1")
    dfs.append(df)

# %%
len(dfs)
# Out:
# 90

# %%
sorted_dfs = []
for df in dfs:
    df=df.sort_values(by=['onset', 'offset'], ascending=[True, False])
    sorted_dfs.append(df)

# %%
dfs = []

for df in sorted_dfs:
    df['CTC'] = ' '
    df['CTC'] =  (df['column'] != df['column'].shift(axis=0)).sum(axis=0)
    dfs.append(df)

# %%
file_names = pd.read_csv('merge_file_names.csv')

# %%
file_names = file_names['header']

# %%
for df in dfs:
    file_name = df['file'][0]
    df.to_csv(f"{file_name}.csv")

# %%
import pandas as pd
import glob

folder = 'RY merges'
file = glob.glob(folder + "\*.csv")

# %%
dfs = []
for file in file:
    df = pd.read_csv(file)
    dfs.append(df)

# %%
sorted_dfs = []
for df in dfs:
    df=df.sort_values(by=['onset', 'offset'], ascending=[True, False])
    sorted_dfs.append(df)

# %%
dfs = []

for df in sorted_dfs:
    df['CTC'] = ' '
    df['CTC'] =  (df['column'] != df['column'].shift(axis=0)).sum(axis=0)
    dfs.append(df)

# %%
for df in dfs:
    file_name = df['file'][0]
    df.to_csv(f"{file_name}.csv")

# %%
import pandas as pd
import glob

folder = 'Session 2 Merges'
file = glob.glob(folder + "\*.csv")

# %%
[f for f in file]
# Out:
# []

# %%
len(file)
# Out:
# 0

# %%
dfs = []
for file in file:
    df = pd.read_csv(file, encoding = "ISO-8859-1")
    dfs.append(df)

# %%
sorted_dfs = []
for df in dfs:
    df=df.sort_values(by=['onset', 'offset'], ascending=[True, False])
    sorted_dfs.append(df)

# %%
dfs = []

for df in sorted_dfs:
    df['CTC'] = ' '
    df['CTC'] =  (df['column'] != df['column'].shift(axis=0)).sum(axis=0)
    dfs.append(df)

# %%
for df in dfs:
    file_name = df['file'][0]
    df.to_csv(f"VS2_CTC_{file_name}.csv")

# %%
import pandas as pd
import glob

folder = 'CTC_VS2'
file = glob.glob(folder + "\*.csv")

# %%
dfs = []

for file in file:
    df = pd.read_csv(file)
    df = df.loc[0, 'file':'CTC']
    dfs.append(df)

# %%
frame = pd.concat(dfs, axis=1)

# %%
frame=frame.T

# %%
frame = frame.drop(columns=['column', 'ordinal', 'onset', 'utts', 'key'])

# %%
frame = frame.drop(columns=['offset'])

# %%
frame.to_csv('VS2_CTC_Totals.csv')
